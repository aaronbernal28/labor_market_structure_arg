# %%
import pandas as pd
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

def read_csv_with_user_agent(url) -> pd.DataFrame:
	return pd.read_csv(url, storage_options={
				"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
			})

# %%
dat = read_csv_with_user_agent("https://rplumber.ilo.org/data/indicator?id=EMP_TEMP_SEX_OC2_NB_A&timefrom=2015&timeto=2025&type=label&format=.csv")
dat
# Out:
# /tmp/ipykernel_34771/2105037987.py:8: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat = pd.read_csv(
#        ref_area.label               source.label  \
# 0         Afghanistan  LFS - Labour Force Survey
# 1         Afghanistan  LFS - Labour Force Survey
# 2         Afghanistan  LFS - Labour Force Survey
# 3         Afghanistan  LFS - Labour Force Survey
# 4         Afghanistan  LFS - Labour Force Survey
# ...               ...                        ...
# 116207       Zimbabwe  LFS - Labour Force Survey
# 116208       Zimbabwe  LFS - Labour Force Survey
# 116209       Zimbabwe  LFS - Labour Force Survey
# 116210       Zimbabwe  LFS - Labour Force Survey
# 116211       Zimbabwe  LFS - Labour Force Survey
#
#                                           indicator.label sex.label  \
# 0       Employment by sex and occupation - ISCO level ...     Total
# 1       Employment by sex and occupation - ISCO level ...     Total
# ...

# %%
dat = read_csv_with_user_agent("https://rplumber.ilo.org/data/indicator?id=EMP_TEMP_SEX_OC2_NB_A&timefrom=2015&timeto=2025&type=label&format=.csv")
dat
# Out:
# /tmp/ipykernel_34771/3488283287.py:8: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(url, storage_options={
#        ref_area.label               source.label  \
# 0         Afghanistan  LFS - Labour Force Survey
# 1         Afghanistan  LFS - Labour Force Survey
# 2         Afghanistan  LFS - Labour Force Survey
# 3         Afghanistan  LFS - Labour Force Survey
# 4         Afghanistan  LFS - Labour Force Survey
# ...               ...                        ...
# 116207       Zimbabwe  LFS - Labour Force Survey
# 116208       Zimbabwe  LFS - Labour Force Survey
# 116209       Zimbabwe  LFS - Labour Force Survey
# 116210       Zimbabwe  LFS - Labour Force Survey
# 116211       Zimbabwe  LFS - Labour Force Survey
#
#                                           indicator.label sex.label  \
# 0       Employment by sex and occupation - ISCO level ...     Total
# ...

# %%
dat["classif1.label"].value_counts()
# Out:
# classif1.label
# Occupation (ISCO-08), 2 digit level: Total                                                            2679
# Occupation (ISCO-08), 2 digit level: 51 - Personal service workers                                    2671
# Occupation (ISCO-08), 2 digit level: 52 - Sales workers                                               2670
# Occupation (ISCO-08), 2 digit level: 61 - Market-oriented skilled agricultural workers                2670
# Occupation (ISCO-08), 2 digit level: 23 - Teaching professionals                                      2669
#                                                                                                       ...
# Occupation (ISCO-88), 2 digit level: 31 - Physical and engineering science associate professionals     102
# Occupation (ISCO-88), 2 digit level: Not elsewhere classified                                          102
# Occupation (ISCO-88), 2 digit level: 11 - Legislators and senior officials                              99
# ...
